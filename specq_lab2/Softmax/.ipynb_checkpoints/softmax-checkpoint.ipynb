# %% [markdown]
# # Softmax exercise
#
# We will implement a softmax classifier that is trained on the CIFAR10 dataset. The output is a model that is able to classify the input image into the 10 different classes of the CIFAR10 dataset.
#
# Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission.
#
# You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - use a validation set to **tune the learning rate** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from data_utils import load_CIFAR10
import matplotlib.pyplot as plt
import time
import pickle

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = '../data/cifar-10-batches-py'
    X_train, y_train = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# Files already downloaded and verified
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **linear_classifier.py**. This is where the method **softmax_loss_vectorized** will be implemented. This method just returns the loss and gradient after applying the softmax function.

# %%
from linear_classifier import Softmax, softmax_loss_vectorized
W = np.random.randn(3073, 10) * 0.0001
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_val, y_val)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))
# Out:
# vectorized loss: 2.372373e+00 computed in 0.080718s

# %% [markdown]
# ## In the file linear_classifier.py, implement SGD in the function LinearClassifier.train() and call this function to do the training.
# ## Write the LinearSVM.predict() function and call this function to evaluate the performance on both the training and validation set

# %%
# Use the validation set to tune hyperparameters (learning rate). 
# You should experiment with different ranges for the learning
# rates; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
results = {}
best_val = -1
best_softmax = None
learning_rates = np.logspace(-7, -5)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning.                                  #
# Save the best trained softmax classifer in best_softmax.                     #
################################################################################
for learning_rate in learning_rates:
        lc_object = Softmax()

        # Train the model
        lc_object.train(X_train,y_train,learning_rate, num_iters = 50000)

        # Predict the output
        y_train_pred = lc_object.predict(X_train)
        y_val_pred = lc_object.predict(X_val)

        # Compute the accuracy
        train_accuracy = np.mean(y_train_pred == y_train)
        val_accuracy = np.mean(y_val_pred == y_val)
        results[learning_rate] = [train_accuracy, val_accuracy]
        
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = lc_object
            
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr in sorted(results):
    train_accuracy, val_accuracy = results[lr]
    print('lr %e train accuracy: %f val accuracy: %f' % (
                lr, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-07 train accuracy: 0.401082 val accuracy: 0.398000
# lr 1.098541e-07 train accuracy: 0.406959 val accuracy: 0.383000
# lr 1.206793e-07 train accuracy: 0.406082 val accuracy: 0.393000
# lr 1.325711e-07 train accuracy: 0.411571 val accuracy: 0.372000
# lr 1.456348e-07 train accuracy: 0.416041 val accuracy: 0.395000
# lr 1.599859e-07 train accuracy: 0.419347 val accuracy: 0.395000
# lr 1.757511e-07 train accuracy: 0.419163 val accuracy: 0.397000
# lr 1.930698e-07 train accuracy: 0.424327 val accuracy: 0.382000
# lr 2.120951e-07 train accuracy: 0.428367 val accuracy: 0.388000
# lr 2.329952e-07 train accuracy: 0.430408 val accuracy: 0.405000
# lr 2.559548e-07 train accuracy: 0.432694 val accuracy: 0.394000
# lr 2.811769e-07 train accuracy: 0.436306 val accuracy: 0.379000
# lr 3.088844e-07 train accuracy: 0.436184 val accuracy: 0.392000
# lr 3.393222e-07 train accuracy: 0.439939 val accuracy: 0.385000
# lr 3.727594e-07 train accuracy: 0.443612 val accuracy: 0.403000
# lr 4.094915e-07 train accuracy: 0.445122 val accuracy: 0.388000
# lr 4.498433e-07 train accuracy: 0.444388 val accuracy: 0.389000
# lr 4.941713e-07 train accuracy: 0.445531 val accuracy: 0.401000
# lr 5.428675e-07 train accuracy: 0.450939 val accuracy: 0.393000
# lr 5.963623e-07 train accuracy: 0.454163 val accuracy: 0.406000
# lr 6.551286e-07 train accuracy: 0.453286 val accuracy: 0.397000
# lr 7.196857e-07 train accuracy: 0.451878 val accuracy: 0.390000
# lr 7.906043e-07 train accuracy: 0.455469 val accuracy: 0.391000
# lr 8.685114e-07 train accuracy: 0.457673 val accuracy: 0.400000
# lr 9.540955e-07 train accuracy: 0.457694 val accuracy: 0.398000
# lr 1.048113e-06 train accuracy: 0.461327 val accuracy: 0.399000
# lr 1.151395e-06 train accuracy: 0.457755 val accuracy: 0.400000
# lr 1.264855e-06 train accuracy: 0.461837 val accuracy: 0.384000
# lr 1.389495e-06 train accuracy: 0.465939 val accuracy: 0.394000
# lr 1.526418e-06 train accuracy: 0.465918 val accuracy: 0.376000
# lr 1.676833e-06 train accuracy: 0.461224 val accuracy: 0.376000
# lr 1.842070e-06 train accuracy: 0.464837 val accuracy: 0.390000
# lr 2.023590e-06 train accuracy: 0.462449 val accuracy: 0.400000
# lr 2.222996e-06 train accuracy: 0.460898 val accuracy: 0.393000
# lr 2.442053e-06 train accuracy: 0.460653 val accuracy: 0.375000
# lr 2.682696e-06 train accuracy: 0.463224 val accuracy: 0.384000
# lr 2.947052e-06 train accuracy: 0.463837 val accuracy: 0.372000
# lr 3.237458e-06 train accuracy: 0.465245 val accuracy: 0.380000
# lr 3.556480e-06 train accuracy: 0.468653 val accuracy: 0.372000
# lr 3.906940e-06 train accuracy: 0.453224 val accuracy: 0.364000
# lr 4.291934e-06 train accuracy: 0.458082 val accuracy: 0.376000
# lr 4.714866e-06 train accuracy: 0.457490 val accuracy: 0.358000
# lr 5.179475e-06 train accuracy: 0.449224 val accuracy: 0.356000
# lr 5.689866e-06 train accuracy: 0.435041 val accuracy: 0.358000
# lr 6.250552e-06 train accuracy: 0.397612 val accuracy: 0.345000
# lr 6.866488e-06 train accuracy: 0.442490 val accuracy: 0.350000
# lr 7.543120e-06 train accuracy: 0.424408 val accuracy: 0.357000
# lr 8.286428e-06 train accuracy: 0.406633 val accuracy: 0.335000
# lr 9.102982e-06 train accuracy: 0.393633 val accuracy: 0.311000
# lr 1.000000e-05 train accuracy: 0.391857 val accuracy: 0.335000
# best validation accuracy achieved during cross-validation: 0.406000

# %%
# evaluate on val set
# Evaluate the best softmax on val set
y_val_pred = best_softmax.predict(X_val)
val_accuracy = np.mean(y_val == y_val_pred)
print('softmax on raw pixels final test set accuracy: %f' % (val_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.406000

# %% [markdown]
# Save the best_softmax weights using pickle:

# %%
with open('softmax_weights.pkl', 'wb') as f:
    pickle.dump(best_softmax.W, f)

# %% [markdown]
# Load the best_softmax weights using pickle:

# %%
with open('softmax_weights.pkl', 'rb') as f:
    W = pickle.load(f)
new_softmax = Softmax()
new_softmax.W = W.copy()

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
